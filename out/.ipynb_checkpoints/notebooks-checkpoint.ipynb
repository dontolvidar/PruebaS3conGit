# %% [markdown]
# # Mi primer notebook usando jupyter lab

# %% [markdown]
# Este es mi primer notebook usando jupyter / jupyter lab genial.\
# La verdad que se ve mejor trabajado desde aquí.
#
# $\int x^2 dx$
#
# Sinceramente super bello.\
#
#
# Ahora vamos a colocar formato de código:
# ```
# print("que tal")
# ```
# Colocaremos link:
# [Guía Markdown](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# ```{note}
# Here is a note
# ```

# %% [markdown]
# ````{margin}
# ```{note}
# Here's my note!
# ```
# ````

# %% [markdown]
# ```{admonition} esto es una advertencia
# si lees esto es porque lo lograste
# ```

# %% [markdown]
# :::{note}
# este texto es **lo normal**, _Markdown del casual_
# :::

# %% [markdown]
# ::::{important}
# :::{note}
# This text is **standard** _Markdown_
# :::
# ::::

# %% [markdown]
# |NOMBRE|APELLIDO|EDAD|
# |---|---|---|
# |Yes|Arias|24|
# |Angelica|Camacho|18|

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/y881t8ilMyc" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/y881t8ilMyc" frameborder="0" allowfullscreen></iframe>

# %%
# %%html
# <iframe width="723" height="407" src="https://www.youtube.com/embed/y881t8ilMyc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="723" height="407" src="https://www.youtube.com/embed/y881t8ilMyc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
#import * from Ipython 
from IPython.display import YouTubeVideo

YouTubeVideo('oV1LVvLWXcM',wigth=800, height=400)
